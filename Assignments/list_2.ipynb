# %% [markdown]
# 1. Write a Python program to sum all the items in a list.

# %%
my_list=[23,34,45,56,12]
## total_sum=sum(my_list)
total_sum=0

for num in my_list:
    total_sum+=num
print(total_sum)
# Out:
# 170

# %% [markdown]
# 2. Write a Python program to multiplies all the items in a list.

# %%
from functools import reduce
my_list=[23,34,45,56,12]

multiple=1

for num in my_list:
    multiple*=num
print(num)

multiple=reduce(lambda a,b : a*b,my_list)
# Out:
# 12
