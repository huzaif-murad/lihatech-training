# %%
a=10
b=20.4
c="Hello World"

print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
import math
math.sqrt(1)
# Out:
# 1.0

# %%
import keyword
keyword_list=list(keyword.kwlist)
# print(list(keyword.kwlist))

for index,item in enumerate(keyword_list):
    print(index," ",item)

# %%
#data types in python

#Numric 

integer_num=10
float_num=11.2
complex_num=45j

#boolean


#String
sentence="He said, \"I can't come tommorrow.\""
print(sentence)
name="Huzaif"
name_1='Huzaif'

print(type(name))
print(type(name_1))

#List
my_list=[23,34,54,"Huzai'f"]
print(my_list)

#Tuple

my_tuple=(23,34,"Huzaif")
print(my_tuple)
# Out:
# He said, "I can't come tommorrow."
# <class 'str'>
# <class 'str'>
# [23, 34, 54, "Huzai'f"]
# (23, 34, 'Huzaif')

# %%
'\u2220'
# Out:
# '∠'

# %%
#String methods

name="Huzaif"
# index=name.index("ZA")
# print(index)
# print(name.index(""))
# help(str.index)

name.upper()
name.lower()

str="     my name is Huzaif     "
print(str.strip())

str_2="   ## @ My name is Huzaif   +*"
print(str_2.strip('# @ + *'))

str_3="python      is   simple."
my_list=str_3.split()
" ".join(my_list)

date=["08","August","2026"]

"/".join(date)

human="HuZAif"
print(human.swapcase())
# Out:
# my name is Huzaif
# My name is Huzaif
# hUzaIF

# %%
#List - collection of heterogenous data, enclosed in square brackets

my_list=[23,34,45,"Huzaif"]

my_list[0]="Murad"

my_list.append(1234)

my_list.extend("Hello")
my_list.extend(["hi","bye"])
my_list


# my_list.pop() #removes last element
# my_list
#creating empty list
# empty_list_1=list()

# empty_list_2=[]
# Out:
# ['Murad', 34, 45, 'Huzaif', 1234, 'H', 'e', 'l', 'l', 'o', 'hi', 'bye']

# %%
#removes first occurance of the specified 
my_list.remove("Murad")
my_list
# Out:
# [34, 45, 'Huzaif', 1234, 'H', 'e', 'l', 'l', 'o', 'hi', 'bye']

# %%
f=[1,2,3,4,5]
f_copy=f.copy()
# f_copy[0]=100
f.append(500)
f_copy
# Out:
# [1, 2, 3, 4, 5]

# %%
id(f),id(f_copy)
# Out:
# (2028483314496, 2028483683712)

# %%
new_copy=f
new_copy.append(101000)
f
id(f),id(new_copy)
# Out:
# (2028483314496, 2028483314496)

# %%
f.append([23,34])
f_copy=f.copy()

f_copy[-1][1]=2000

f_copy
# Out:
# [1, 2, 3, 4, 5, 500, 101000, 101000, [23, 2000]]

# %%
f
# Out:
# [1, 2, 3, 4, 5, 500, 101000, 101000, [23, 2000]]

# %%
c =[10,20,30]
# c.insert(0,300)
c.append(4000)
c.extend([23,43,54,454])
c.pop()
c.insert(4,200)

c.reverse()
c.sort()
# Out:
# [10, 20, 23, 30, 43, 54, 200, 4000]

# %%
c.sort(reverse=True)
c
# Out:
# [4000, 200, 54, 43, 30, 23, 20, 10]

# %%
#Tuple - 
# 1.It's immutable 
# 2.faster than list because of immutability

# %%
# Set - 
# Collection of unique elements
# Duplicates are not allowed
# Unorderd collection

s=set()

s2={()}

print(s)
print(s2)

s3={23,34,34,45,56,45}
s3
# Out:
# set()
# {()}
# {23, 34, 45, 56}

# %%
s1=set()

s1.add(23)
s1
# Out:
# {23}

# %%
# s1.update("string")
s1.update(["huzaif",34,45])
s1
# Out:
# {23, 34, 45, 'huzaif'}

# %%
set_1={10,30,40}
set_2={20,30,40}

set_1.union(set_2)
set_1.intersection(set_2)
set_1.difference(set_2)
set_1.symmetric_difference(set_2)
# Out:
# {10, 20}

# %%
#Assignment : check pop remove, discard

# %%
my_dict={
    'name':'huzaif',
    'age': 23,
    'city':'new york'
}

my_dict['salary'] = 45000

my_dict.items()

my_dict.setdefault('pin code',416505)
my_dict.setdefault('name')
my_dict.setdefault('state')
my_dict
# Out:
# {'name': 'huzaif',
#  'age': 23,
#  'city': 'new york',
#  'salary': 45000,
#  'pin code': 416505,
#  'state': None}

# %%
a=['name','roll no']
b=['Huzaif',23]

# dict(zip(a,b))

# %%
##Importan built in function in function

print(10,20,30,sep="-")

for i in range(5):
    for j in range(i):
        print("*",end=" ")
    print()
# Out:
# 10-20-30
#
# *
# * *
# * * *
# * * * *

# %%
n=5
for i in range(n,0,-1):
    for j in range(i):
        print("*",end=" ")
    print()
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
#enumerate function : it gives index and value pair.
# d=[10,20,30,40,50]
# del dict
# list(enumerate(d))
# # for index,value in enumerate(d):
# #     print(index," ", value)
# dict(enumerate(d))
# Out:
# {0: 10, 1: 20, 2: 30, 3: 40, 4: 50}

# %%
# num=int(input("Enter a number : "))
# print(num)

my_list=list(map(int,input().split()))
print(my_list)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 4
#       1 # num=int(input("Enter a number : "))
#       2 # print(num)
#       3
# ----> 4 my_list=list(map(int,input().split()))
#       5 print(my_list)
#
# ValueError: invalid literal for int() with base 10: '[12,23,34]'

# %% [markdown]
# ## programiz

# %%
l1=eval(input("enter elements of the list"))

print(l1,type(l1))
# Out:
# {'name': 'huzaif'} <class 'dict'>

# %%
num=23.45456

round(num,2)
round(num)
# Out:
# 23

# %%
new_list=[10,20,30,40,50]

print(sum(new_list))
print(max(new_list))
print(min(new_list))
print(len(new_list))

avg=sum(new_list)//len(new_list)
print(avg)
# Out:
# 150
# 50
# 10
# 5
# 30

# %%
a=sorted("huzaif")
a

# print(sorted([]))

# print(sorted((43,54,23,34)))

t=['ashutosh','shubham','Aakash','Rana']
sorted(t,key=str.lower)
# Out:
# ['Aakash', 'ashutosh', 'Rana', 'shubham']

# %%
num=int(input("Enter a number : "))

if num>0:
    print("Positive number")
elif num<0:
    print("Negative number")
else:
    print("Zero")
# Out:
# Negative number

# %%
age=int(input("Enter your age : "))
nationality=input("Enter your nationality : ").lower()

if age>=18 and nationality.lower()=="indian":
    print("You are eligible to vote")
else:
    print("You are not eligible to vote")
# Out:
# You are eligible to vote

# %%
# list=list(map(int,input("Enter elements of the list : ").split()))
# print(list)

# %%
num_1=23
num_2=450


num_3=50

if num_1>num_2 and num_1>num_3:
    print(num_1," is the largest number")   
elif num_2>num_1 and num_2>num_3:
    print(num_2," is the largest number")
else:
    print(num_3," is the largest number")
# Out:
# 450  is the largest number

# %%
# nums=[10,20,11,3,51]

# odd_numbers=list(filter(lambda x:x%2!=0,nums))

# %%
marks='parth got 80 90 77 89'

new_list=marks.split()
sum=0
for item in new_list:
    if item.isdigit():
        sum+=int(item)

print(sum)
# Out:
# 336

# %%
marks='parth got 80 90 77 89'

# result=list(filter(lambda x:x.isdigit(),marks))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[89], line 3
#       1 marks='parth got 80 90 77 89'
#       2
# ----> 3 result=list(filter(lambda x:x.isdigit(),marks))
#
# TypeError: 'map' object is not callable
