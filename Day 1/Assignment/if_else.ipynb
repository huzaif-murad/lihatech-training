# %% [markdown]
# #### 01.Write a Python program to find maximum between two numbers.

# %%
a=5
b=10

if a>b:
    print("Maximum number is : ",a)
else:
    print("Maximum number is : ",b)
# Out:
# Maximum number is :  10

# %% [markdown]
# #### 02.Write a Python program to find maximum among three numbers.

# %%
a=int(input())
b=int(input())
c=int(input())

if a>b and a>c:
    print("Maximum is :",a)
elif b>a and b>c:
    print("Maximum is :",b)
else:
   print("Maximum is :",c)
# Out:
# Maximum is : 7

# %% [markdown]
# #### 03.Write a Python program to check whether a number is negative, positive or zero.

# %%
n=int(input())

if n>0:
    print(n,"is a positive number.")
elif n<0:
    print(n,"is a negative number.")
else:
    print(n,"is equal to zero (not a positive or negative number).")
# Out:
# 8 is a positive number.

# %% [markdown]
# #### 04.Write a Python program to check whether a number is divisible by 5 and 11 or not.

# %%
n=int(input())

if n%5==0 and n%11==0:
    print(n,"is divisible by 5 and 11.")
else:
    print(n,"is not divisible by 5 and 11")
# Out:
# 55 is divisible by 5 and 11.

# %% [markdown]
# #### 05.Write a Python program to check whether a number is even or odd.

# %%
n=int(input())

if n%2==0:
    print("even number.")
else:
    print("odd number.")
# Out:
# even number.

# %% [markdown]
# #### 06.Write a Python program to check whether a year is leap year or not.

# %%
year=int(input())

if year%4==0:
    print("leap year")
else:
    print("not a leap year")
# Out:
# not a leap year

# %% [markdown]
# #### 07.Write a Python program to check whether a character is alphabet or not.

# %%
char=input()

if char.isdigit() and char.isalnum():
    print("entered character is not an alphabet.")
    
else:
    print("entered character is an alphabet.")
# Out:
# entered character is not an alphabet.

# %% [markdown]
# #### 08.Write a Python program to input any alphabet and check whether it is vowel or consonant.

# %%
character=input()

vowels="aeiou"

if character.lower() in vowels:
    print("character is a vowel")
else:
    print("character is a consonent")
# Out:
# character is a consonent

# %% [markdown]
# #### 09.Write a Python program to check whether a character is uppercase or lowercase alphabet.

# %%
char=input()

if char == char.lower():
    print("character is in lowercase.")
else:
    print("character is in uppercase.")
# Out:
# character is in lowercase.

# %% [markdown]
# #### 10.Write a Python program to input angles of a triangle and check whether triangle is valid or not.

# %%
angle_1=int(input())
angle_2=int(input())
angle_3=int(input())

sum_of_angles=angle_1+angle_2+angle_3

if sum_of_angles == 180:
    print("Valid traingle.")
else:
    print("Not a valid triangle.")
# Out:
# Not a valid triangle.

# %% [markdown]
# #### 11.Write a Python program to check whether the triangle is equilateral, isosceles or scalene triangle.

# %% [markdown]
# #### 12.Write a Python program to calculate profit or loss. Input is selling cost and actual cost.

# %%
actual_cost=int(input())
selling_cost=int(input())

if actual_cost>selling_cost:
    print(f"""Loss of {actual_cost-selling_cost}Rs.""")
else:
    print("Profit of",selling_cost-actual_cost,"Rs.")
# Out:
# Loss of 50Rs.

# %% [markdown]
# #### 15.Write a Python program to input marks of five subjects Physics, Chemistry,
# #### Biology, Mathematics and Computer. Calculate percentage and grade
# #### according to following:
# #### Percentage >= 90% : Grade A
# #### Percentage >= 80% : Grade B
# #### Percentage >= 70% : Grade C
# #### Percentage >= 60% : Grade D
# #### Percentage >= 40% : Grade E
# ##### Percentage < 40% : Grade F

# %%
marks=map(int,input().split())

percentage=round(((sum(marks)/500)*100),2)

if percentage>=90:
    print("Grade : A,","Percentage :",percentage)
elif percentage>=80:
    print("Grade : B","Percentage :",percentage)
elif percentage>=70:
    print("Grade : C,","Percentage :",percentage)
elif percentage>=60:
    print("Grade : D,","Percentage :",percentage)
elif percentage>=40:
    print("Grade : E,","Percentage :",percentage)
else:
    print("Grade : F,","Percentage :",percentage)
# Out:
# Grade : E, Percentage : 59.2

# %% [markdown]
# #### 17.Write a Python program to input electricity unit charges and calculate total
# #### electricity bill according to the given condition:
# #### For first 50 units Rs. 0.50/unit
# #### For next 100 units Rs. 0.75/unit
# #### For next 100 units Rs. 1.25/unit
# #### For unit above 250 Rs. 1.50/unit
# #### An additional surcharge of 17% is added to the bill

# %%
units=int(input())
bill=0
if units<=50:
    bill+=units*0.5
elif units<=150:
    bill=(100*0.75)+(50*0.5)
    
elif units<=250:
    bill=(100*1.25)+(100*0.75)+(50*0.5)
else:
    bill=(100*1.25)+(100*0.75)+(50*0.5)+((units-250)*1.5)
    

total_bill=round((17/100)*bill)+bill

print(total_bill)
# Out:
# 351.0
